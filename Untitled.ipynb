# %%
import numpy as  np
from matplotlib.pyplot import *
#%matplotlib notebook
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

# %%
color = ['red', 'green', 'yellow', 'lime', 'burlywood','chartreuse']

# %%
x, P = np.loadtxt('P.dat',unpack=True)
x, Q = np.loadtxt('Q.dat',unpack=True)

plot(x,P)
plot(x,Q)
grid(True)
show()
for i in range(x.size):
    plot(x[i], 0, 'o',color=color[int(P[i])])
show()
for i in range(x.size):
    plot(x[i], 0, 'o',color=color[int(Q[i])])
show()

# %%
xx, yy, P2 = np.loadtxt('P2.dat',unpack=True)
xx.size

# %%
for i in range(xx.size):
    plot(xx[i], yy[i], 'o',color=color[int(P2[i])])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np

# %%
inf, sup, N = np.loadtxt('config.weird')
N = int(N)
np.linspace(inf, sup, N)

x = np.linspace(inf, sup, N)
y = np.linspace(inf, sup, N)
X, Y = np.meshgrid(x, y)

# %%
P2 = np.loadtxt('P2H.dat')
plt.contour(X, Y, P2, colors='black');

# %%
Q2 = np.loadtxt('Q2H.dat')
plt.contour(X, Y, Q2,colors='black')

# %%
T2 = np.loadtxt('T2H.dat')
plt.contour(X, Y, T2, colors='blue');

# %%
inf, sup, N = np.loadtxt('config.weird')
N = int(N)
np.linspace(inf, sup, N)

x = np.linspace(inf, sup, N)
y = np.linspace(inf, sup, N)
X, Y = np.meshgrid(x, y)

P2 = np.loadtxt('P2H.dat')
plt.contour(X, Y, P2, colors='black');
Q2 = np.loadtxt('Q2H.dat')
plt.contour(X, Y, Q2,colors='blue')
plt.show()
